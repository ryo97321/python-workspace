# %%
#matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.random.rand(5)
y *= 5

# %%
plt.plot(y)

# %%
x = np.arange(1, 11, 2)
y = np.random.rand(5)
y *= 5
plt.plot(x, y)

# %%
plt.plot(x, y, linestyle="--", marker="^", color="r")

# %%
x = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
y = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.title("Year - Count")
plt.xlabel("Year")
plt.ylabel("Count")
plt.grid(True)

plt.plot(x, y)

# %%
year = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
count = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.bar(year, count)
# Out:
# <BarContainer object of 8 artists>

# %%
year = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
count = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.barh(year, count)
# Out:
# <BarContainer object of 8 artists>

# %%
english = np.array([70, 95, 83, 100, 72, 71, 75, 85, 67, 75])
math = np.array([90, 82, 100, 95, 50, 81, 52, 56, 67, 71])

plt.scatter(english, math)

# %%
fruits = np.array(["peach", "orange", "grape", "banana", "apple"])
count = np.array([20, 20, 20, 20, 20])

plt.pie(count, labels = fruits, autopct = "%.1f%%", startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e7aa6b40d0>,
#   <matplotlib.patches.Wedge at 0x1e7aa6b44f0>,
#   <matplotlib.patches.Wedge at 0x1e7aa6b49d0>,
#   <matplotlib.patches.Wedge at 0x1e7aaa096a0>,
#   <matplotlib.patches.Wedge at 0x1e7aa698e50>],
#  [Text(-0.6465637858537404, 0.8899186877588754, 'peach'),
#   Text(-1.046162158377023, -0.33991872319707317, 'orange'),
#   Text(5.149471664411206e-08, -1.0999999999999988, 'grape'),
#   Text(1.0461621902025062, -0.33991862524830185, 'banana'),
#   Text(0.6465637025335375, 0.8899187482945414, 'apple')],
#  [Text(-0.35267115592022197, 0.4854101933230229, '20.0%'),
#   Text(-0.5706339045692853, -0.18541021265294896, '20.0%'),
#   Text(2.8088027260424755e-08, -0.5999999999999993, '20.0%'),
#   Text(0.5706339219286397, -0.18541015922634643, '20.0%'),
#   Text(0.3526711104728386, 0.4854102263424771, '20.0%')])

# %%
y1 = np.random.rand(11)
y2 = np.random.rand(11)

plt.plot(y1, color="blue", label="y1")
plt.plot(y2, color="red", label="y2")
plt.legend(loc = "upper right")

# %%
y1 = np.random.rand(11)
y2 = np.random.rand(11)

fig = plt.figure()

sp1 = fig.add_subplot(1, 2, 1)
sp1.plot(y1)

sp2 = fig.add_subplot(1, 2, 2)
sp2.plot(y2)

# %%
x = np.array([20, 30, 40, 50, 60])
y = np.array([30, 38, 41, 49, 62])

p = np.polyfit(x, y, 1)

f = np.poly1d(p)

plt.scatter(x, y)
plt.plot(x, f(x))
